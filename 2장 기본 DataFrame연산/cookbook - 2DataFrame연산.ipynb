# %%
import pandas as pd
import numpy as np

movies = pd.read_csv("movie.csv")

# %%
movie_actor_director = movies[["actor_1_name", "actor_2_name", "actor_3_name", "director_name"]]

# %%
movie_actor_director.head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
type(movies[["director_name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies["director_name"])
# Out:
# pandas.core.series.Series

# %%
movies[["director_name"]]
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %%
movies["director_name"]
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
type(movies.loc[:,["director_name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies.loc[:,"director_name"])
# Out:
# pandas.core.series.Series

# %%
type(movies.loc[:,["director_name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
cols = ["actor_1_name", "actor_2_name", "actor_3_name", "director_name",]

# %%
movie_actor_director = movies[cols]

# %%
def shorten(col):
    return(
        str(col).replace("facebook_like", "fb").replace("_for_reviews", "")
    )

# %%
movies = movies.rename(columns = shorten)

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
movies.select_dtypes(include="int").head()
# Out:
#    num_voted_users  cast_total_fbs  movie_fbs
# 0           886204            4834      33000
# 1           471220           48350          0
# 2           275868           11700      85000
# 3          1144337          106759     164000
# 4                8             143          0

# %%
numeric_movies = movies.select_dtypes(include="number")

# %%
movies.select_dtypes(include = ["int", "object"]).head()
# Out:
#    color      director_name      actor_2_name  ... country content_rating movie_fbs
# 0  Color      James Cameron  Joel David Moore  ...     USA          PG-13     33000
# 1  Color     Gore Verbinski     Orlando Bloom  ...     USA          PG-13         0
# 2  Color         Sam Mendes      Rory Kinnear  ...      UK          PG-13     85000
# 3  Color  Christopher Nolan    Christian Bale  ...     USA          PG-13    164000
# 4    NaN        Doug Walker        Rob Walker  ...     NaN            NaN         0
#
# [5 rows x 15 columns]

# %%
movies.select_dtypes(exclude="float").head()
# Out:
#    color      director_name      actor_2_name  ... country content_rating movie_fbs
# 0  Color      James Cameron  Joel David Moore  ...     USA          PG-13     33000
# 1  Color     Gore Verbinski     Orlando Bloom  ...     USA          PG-13         0
# 2  Color         Sam Mendes      Rory Kinnear  ...      UK          PG-13     85000
# 3  Color  Christopher Nolan    Christian Bale  ...     USA          PG-13    164000
# 4    NaN        Doug Walker        Rob Walker  ...     NaN            NaN         0
#
# [5 rows x 15 columns]

# %%
movies.filter(like="fb").head()
# Out:
#    director_fbs  actor_3_fbs  ...  actor_2_fbs  movie_fbs
# 0           0.0        855.0  ...        936.0      33000
# 1         563.0       1000.0  ...       5000.0          0
# 2           0.0        161.0  ...        393.0      85000
# 3       22000.0      23000.0  ...      23000.0     164000
# 4         131.0          NaN  ...         12.0          0
#
# [5 rows x 6 columns]

# %%
cols = ["actor_1_name", "actor_2_name", "actor_3_name", "director_name",]

# %%
movies.filter(items=cols).head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
movies.filter(regex= "\d")
# Out:
#       actor_3_fbs      actor_2_name  ...          actor_3_name actor_2_fbs
# 0           855.0  Joel David Moore  ...             Wes Studi       936.0
# 1          1000.0     Orlando Bloom  ...        Jack Davenport      5000.0
# 2           161.0      Rory Kinnear  ...      Stephanie Sigman       393.0
# 3         23000.0    Christian Bale  ...  Joseph Gordon-Levitt     23000.0
# 4             NaN        Rob Walker  ...                   NaN        12.0
# ...           ...               ...  ...                   ...         ...
# 4911        318.0     Daphne Zuniga  ...          Crystal Lowe       470.0
# 4912        319.0     Valorie Curry  ...         Sam Underwood       593.0
# 4913          0.0     Maxwell Moody  ...        David Chandler         0.0
# 4914        489.0     Daniel Henney  ...           Eliza Coupe       719.0
# 4915         16.0  Brian Herzlinger  ...              Jon Gunn        23.0
#
# [4916 rows x 6 columns]

# %%
movies = pd.read_csv("movie.csv")

# %%
movies = movies.rename(columns = shorten)

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic', 'duration', 'director_fbs',
#        'actor_3_fbs', 'actor_2_name', 'actor_1_fbs', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users', 'cast_total_fbs',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_fbs', 'imdb_score', 'aspect_ratio',
#        'movie_fbs'],
#       dtype='object')

# %%
cat_core = ["movie_title", "title_yaer", "content_rating", "genres",]

# %%
cat_people = ["director_name", "actor_1_name", "actor_2_name", "actor_3_name",]

# %%
cat_other = ["color", "country", "language", "plot_keywords", "movie_imdb_link",]

# %%
cont_fb = ["director_fb", "actor_1_fb", "actor_2_fb", "actor_3_fb", "cast_total_fb", "movie_fb",]

# %%
cont_finance = ["budget", "gross"]

# %%
cont_num_reviews = ["num_voted_users", "num_user", "num_critic",]

# %%
cont_other = ["imdb_score", "duration", "aspect_ratio", "facenumber_in_poster",]

# %%
new_col_order = (cat_core + cat_people + cat_other + cont_fb + cont_finance + cont_num_reviews + cont_other)

# %%
set(movies.columns) == set(new_col_order)
# Out:
# False

# %%
movies.shape
# Out:
# (4916, 28)

# %%
movies.size
# Out:
# 137648

# %%
movies.ndim
# Out:
# 2

# %%
len(movies)
# Out:
# 4916

# %%
movies.count()
# Out:
# color                   4897
# director_name           4814
# num_critic              4867
# duration                4901
# director_fbs            4814
# actor_3_fbs             4893
# actor_2_name            4903
# actor_1_fbs             4909
# gross                   4054
# genres                  4916
# actor_1_name            4909
# movie_title             4916
# num_voted_users         4916
# cast_total_fbs          4916
# actor_3_name            4893
# facenumber_in_poster    4903
# plot_keywords           4764
# movie_imdb_link         4916
# num_user                4895
# language                4904
# country                 4911
# content_rating          4616
# budget                  4432
# title_year              4810
# actor_2_fbs             4903
# imdb_score              4916
# aspect_ratio            4590
# movie_fbs               4916
# dtype: int64

# %%
movies.describe().T
# Out:
#                        count          mean  ...          75%           max
# num_critic            4867.0  1.379889e+02  ...       191.00  8.130000e+02
# duration              4901.0  1.070908e+02  ...       118.00  5.110000e+02
# director_fbs          4814.0  6.910145e+02  ...       189.75  2.300000e+04
# actor_3_fbs           4893.0  6.312763e+02  ...       633.00  2.300000e+04
# actor_1_fbs           4909.0  6.494488e+03  ...     11000.00  6.400000e+05
# gross                 4054.0  4.764451e+07  ...  61108412.75  7.605058e+08
# num_voted_users       4916.0  8.264492e+04  ...     93772.75  1.689764e+06
# cast_total_fbs        4916.0  9.579816e+03  ...     13616.75  6.567300e+05
# facenumber_in_poster  4903.0  1.377320e+00  ...         2.00  4.300000e+01
# num_user              4895.0  2.676688e+02  ...       320.50  5.060000e+03
# budget                4432.0  3.654749e+07  ...  43000000.00  4.200000e+09
# title_year            4810.0  2.002448e+03  ...      2011.00  2.016000e+03
# actor_2_fbs           4903.0  1.621924e+03  ...       912.00  1.370000e+05
# imdb_score            4916.0  6.437429e+00  ...         7.20  9.500000e+00
# aspect_ratio          4590.0  2.222349e+00  ...         2.35  1.600000e+01
# movie_fbs             4916.0  7.348294e+03  ...      2000.00  3.490000e+05
#
# [16 rows x 8 columns]

# %%
movies.min(skipna = False)
# Out:
# num_critic                                                            NaN
# duration                                                              NaN
# director_fbs                                                          NaN
# actor_3_fbs                                                           NaN
# actor_1_fbs                                                           NaN
# gross                                                                 NaN
# genres                                                             Action
# movie_title                                                       #Horror
# num_voted_users                                                         5
# cast_total_fbs                                                          0
# facenumber_in_poster                                                  NaN
# movie_imdb_link         http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# num_user                                                              NaN
# budget                                                                NaN
# title_year                                                            NaN
# actor_2_fbs                                                           NaN
# imdb_score                                                            1.6
# aspect_ratio                                                          NaN
# movie_fbs                                                               0
# dtype: object

# %%
movies = pd.read_csv("movie.csv")

def shorten(col):
    return col.replace("facebook_likes", "fb").replace(
        "_for_reviews", ""
    )

movies = movies.rename(columns = shorten)
movies.isnull().head()
# Out:
#    color  director_name  num_critic  ...  imdb_score  aspect_ratio  movie_fb
# 0  False          False       False  ...       False         False     False
# 1  False          False       False  ...       False         False     False
# 2  False          False       False  ...       False         False     False
# 3  False          False       False  ...       False         False     False
# 4   True          False        True  ...       False          True     False
#
# [5 rows x 28 columns]

# %%
movies.isnull().sum().head()
# Out:
# color             19
# director_name    102
# num_critic        49
# duration          15
# director_fb      102
# dtype: int64

# %%
movies.isnull().sum().sum()
# Out:
# 2654

# %%
movies.isnull().any().any()
# Out:
# True

# %%
movies.isnull().dtypes.value_counts()
# Out:
# bool    28
# dtype: int64
